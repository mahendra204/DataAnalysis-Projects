# %% [markdown]
# # Exploratory data analysis - Extracting insights from data

# %%
# importing the libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import warnings

# %% [markdown]
# # Reading the data by using pandas library

# %%
emp_payrol=pd.read_csv("employee_payroll.csv")

# %%
emp_payrol
# Out:
#         Fiscal Year  Fiscal Quarter Fiscal Period First Name   Last Name  \
# 0              2016               1        2016Q1     AMRITH       AAKRE
# 1              2016               2        2016Q2     AMRITH       AAKRE
# 2              2016               3        2016Q3     AMRITH       AAKRE
# 3              2016               4        2016Q4     AMRITH       AAKRE
# 4              2017               1        2017Q1     AMRITH       AAKRE
# ...             ...             ...           ...        ...         ...
# 234294         2018               2        2018Q2      NORMA  AMOFA-LOZA
# 234295         2018               2        2018Q2      FRANK    PHILLIPS
# 234296         2018               1        2018Q1    CYNTHIA    KENDRICK
# 234297         2018               1        2018Q1      LAURA      TOLEDO
# 234298         2018               2        2018Q2      NAKIA  WASHINGTON
#
#        Middle Init                          Bureau  Office  \
# ...

# %%
emp_payrol.shape
# Out:
# (234299, 15)

# %%
emp_payrol.columns
# Out:
# Index(['Fiscal Year', 'Fiscal Quarter', 'Fiscal Period', 'First Name',
#        'Last Name', 'Middle Init', 'Bureau', 'Office', 'Office Name',
#        'Job Code', 'Job Title', 'Base Pay', 'Position ID',
#        'Employee Identifier', 'Original Hire Date'],
#       dtype='object')

# %%
emp_payrol.isnull().sum()
# Out:
# Fiscal Year                0
# Fiscal Quarter             0
# Fiscal Period              0
# First Name                 0
# Last Name                  0
# Middle Init            93412
# Bureau                     0
# Office                  3184
# Office Name             3184
# Job Code                   0
# Job Title                  0
# Base Pay                   4
# Position ID                0
# Employee Identifier        0
# Original Hire Date         0
# dtype: int64

# %% [markdown]
# Here we can observe like there are few attributes or features are null values and in that one feature middle init has more no.of
# null values and to analyze the data it wont be effect in any insights so we can drop it.

# %%
emp_payrol.drop('Middle Init',axis=1,inplace=True)

# %%
emp_payrol.shape
# Out:
# (234299, 14)

# %%
emp_payrol.isnull().sum()
# Out:
# Fiscal Year               0
# Fiscal Quarter            0
# Fiscal Period             0
# First Name                0
# Last Name                 0
# Bureau                    0
# Office                 3184
# Office Name            3184
# Job Code                  0
# Job Title                 0
# Base Pay                  4
# Position ID               0
# Employee Identifier       0
# Original Hire Date        0
# dtype: int64

# %%
new_emp=emp_payrol.dropna()

# %%
new_emp
# Out:
#         Fiscal Year  Fiscal Quarter Fiscal Period First Name   Last Name  \
# 0              2016               1        2016Q1     AMRITH       AAKRE
# 1              2016               2        2016Q2     AMRITH       AAKRE
# 2              2016               3        2016Q3     AMRITH       AAKRE
# 3              2016               4        2016Q4     AMRITH       AAKRE
# 4              2017               1        2017Q1     AMRITH       AAKRE
# ...             ...             ...           ...        ...         ...
# 234294         2018               2        2018Q2      NORMA  AMOFA-LOZA
# 234295         2018               2        2018Q2      FRANK    PHILLIPS
# 234296         2018               1        2018Q1    CYNTHIA    KENDRICK
# 234297         2018               1        2018Q1      LAURA      TOLEDO
# 234298         2018               2        2018Q2      NAKIA  WASHINGTON
#
#                                 Bureau  Office  \
# ...

# %% [markdown]
# we can observe Employee Identifier is the feature that won't be much useful to analyze the data so we can also drop that feature

# %%
new_emp.drop('Employee Identifier',axis=1,inplace=True)
# Out:
# C:\Users\mahen\AppData\Local\Temp\ipykernel_38436\3913154111.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_emp.drop('Employee Identifier',axis=1,inplace=True)

# %%
new_emp.shape
# Out:
# (231111, 13)

# %%
new_emp
# Out:
#         Fiscal Year  Fiscal Quarter Fiscal Period First Name   Last Name  \
# 0              2016               1        2016Q1     AMRITH       AAKRE
# 1              2016               2        2016Q2     AMRITH       AAKRE
# 2              2016               3        2016Q3     AMRITH       AAKRE
# 3              2016               4        2016Q4     AMRITH       AAKRE
# 4              2017               1        2017Q1     AMRITH       AAKRE
# ...             ...             ...           ...        ...         ...
# 234294         2018               2        2018Q2      NORMA  AMOFA-LOZA
# 234295         2018               2        2018Q2      FRANK    PHILLIPS
# 234296         2018               1        2018Q1    CYNTHIA    KENDRICK
# 234297         2018               1        2018Q1      LAURA      TOLEDO
# 234298         2018               2        2018Q2      NAKIA  WASHINGTON
#
#                                 Bureau  Office  \
# ...

# %% [markdown]
# we can observe in given data set it has been given like fiscal year and quarte and also given fiscal period by combining those two previous features so we can also remove this feature

# %%
new_emp.drop('Fiscal Period', axis=1, inplace=True)
# Out:
# C:\Users\mahen\AppData\Local\Temp\ipykernel_38436\3603578947.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_emp.drop('Fiscal Period', axis=1, inplace=True)

# %%
new_emp
# Out:
#         Fiscal Year  Fiscal Quarter First Name   Last Name  \
# 0              2016               1     AMRITH       AAKRE
# 1              2016               2     AMRITH       AAKRE
# 2              2016               3     AMRITH       AAKRE
# 3              2016               4     AMRITH       AAKRE
# 4              2017               1     AMRITH       AAKRE
# ...             ...             ...        ...         ...
# 234294         2018               2      NORMA  AMOFA-LOZA
# 234295         2018               2      FRANK    PHILLIPS
# 234296         2018               1    CYNTHIA    KENDRICK
# 234297         2018               1      LAURA      TOLEDO
# 234298         2018               2      NAKIA  WASHINGTON
#
#                                 Bureau  Office  \
# 0                     State's Attorney  1250.0
# 1                     State's Attorney  1250.0
# 2                     State's Attorney  1250.0
# 3                     State's Attorney  1250.0
# ...

# %% [markdown]
# Here if we can observe first and last names are given in two columns so we can combine them into one column like fullname as one feature

# %%
new_emp.columns
# Out:
# Index(['Fiscal Year', 'Fiscal Quarter', 'First Name', 'Last Name', 'Bureau',
#        'Office', 'Office Name', 'Job Code', 'Job Title', 'Base Pay',
#        'Position ID', 'Original Hire Date'],
#       dtype='object')

# %% [markdown]
# change the office as office Id

# %%
new_emp=new_emp.rename(columns={'Office':'Office_id'})

# %%
new_emp
# Out:
#         Fiscal Year  Fiscal Quarter First Name   Last Name  \
# 0              2016               1     AMRITH       AAKRE
# 1              2016               2     AMRITH       AAKRE
# 2              2016               3     AMRITH       AAKRE
# 3              2016               4     AMRITH       AAKRE
# 4              2017               1     AMRITH       AAKRE
# ...             ...             ...        ...         ...
# 234294         2018               2      NORMA  AMOFA-LOZA
# 234295         2018               2      FRANK    PHILLIPS
# 234296         2018               1    CYNTHIA    KENDRICK
# 234297         2018               1      LAURA      TOLEDO
# 234298         2018               2      NAKIA  WASHINGTON
#
#                                 Bureau  Office_id  \
# 0                     State's Attorney     1250.0
# 1                     State's Attorney     1250.0
# 2                     State's Attorney     1250.0
# 3                     State's Attorney     1250.0
# ...

# %%
new_emp['Full_name']=new_emp['First Name']+' '+new_emp['Last Name']

# %%
new_emp
# Out:
#         Fiscal Year  Fiscal Quarter First Name   Last Name  \
# 0              2016               1     AMRITH       AAKRE
# 1              2016               2     AMRITH       AAKRE
# 2              2016               3     AMRITH       AAKRE
# 3              2016               4     AMRITH       AAKRE
# 4              2017               1     AMRITH       AAKRE
# ...             ...             ...        ...         ...
# 234294         2018               2      NORMA  AMOFA-LOZA
# 234295         2018               2      FRANK    PHILLIPS
# 234296         2018               1    CYNTHIA    KENDRICK
# 234297         2018               1      LAURA      TOLEDO
# 234298         2018               2      NAKIA  WASHINGTON
#
#                                 Bureau  Office_id  \
# 0                     State's Attorney     1250.0
# 1                     State's Attorney     1250.0
# 2                     State's Attorney     1250.0
# 3                     State's Attorney     1250.0
# ...

# %% [markdown]
# we have added first and last name as one column so we can remove first and last name columns

# %%
new_emp.drop(columns=['First Name','Last Name'],inplace=True)

# %% [markdown]
# just place the full name as second column

# %%
column_to_move = new_emp.pop('Full_name')
new_emp.insert(2, 'Full_name', column_to_move)

# %%
new_emp
# Out:
#         Fiscal Year  Fiscal Quarter         Full_name  \
# 0              2016               1      AMRITH AAKRE
# 1              2016               2      AMRITH AAKRE
# 2              2016               3      AMRITH AAKRE
# 3              2016               4      AMRITH AAKRE
# 4              2017               1      AMRITH AAKRE
# ...             ...             ...               ...
# 234294         2018               2  NORMA AMOFA-LOZA
# 234295         2018               2    FRANK PHILLIPS
# 234296         2018               1  CYNTHIA KENDRICK
# 234297         2018               1      LAURA TOLEDO
# 234298         2018               2  NAKIA WASHINGTON
#
#                                 Bureau  Office_id  \
# 0                     State's Attorney     1250.0
# 1                     State's Attorney     1250.0
# 2                     State's Attorney     1250.0
# 3                     State's Attorney     1250.0
# 4                     State's Attorney     1250.0
# ...

# %% [markdown]
# # find the total no.of employees

# %%
new_emp['Full_name'].nunique()
# Out:
# 27332

# %% [markdown]
# # names of total employees

# %%
new_emp['Full_name'].unique()
# Out:
# array(['AMRITH AAKRE', 'DAVID AARONS', 'SHABIRHUSAIN ABADIN', ...,
#        'LAVERNE SCOTT', 'ISSAAC LOPEZ', 'ELLIOTT ENGLANDER'], dtype=object)

# %% [markdown]
# # no.of fiscal years that are present in data

# %%
new_emp['Fiscal Year'].nunique()
# Out:
# 3

# %% [markdown]
# # what are the those fiscal years from the given data set

# %%
new_emp['Fiscal Year'].unique()
# Out:
# array([2016, 2017, 2018], dtype=int64)

# %% [markdown]
# # no.of quarters in a fiscal year and those are

# %%
new_emp['Fiscal Quarter'].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
new_emp['Fiscal Quarter'].nunique()
# Out:
# 4

# %% [markdown]
# # no.of distinct bureaus from the given data

# %%
new_emp['Bureau'].unique()
# Out:
# array(["State's Attorney", 'Assessor', 'Bureau of Health',
#        'Bureau of Human Resources', 'Bureau of Admin.',
#        'Bureau of Finance', 'Chief Judge', 'Sheriff', 'Treasurer',
#        'Office Under the President', 'County Clerk', 'Public Defender',
#        'Clerk of Circuit Ct.', 'Recorder of Deeds',
#        'Bureau of Technology', 'Facilities Management', 'Board of Review',
#        'Inspector General', 'Bureau of Economic Development',
#        'Cnty Brd Commissions', 'County Auditor',
#        'Administrative Hearing Board', 'Public Admin.',
#        'Board of Elections', 'PUBLIC GUARDIAN', 'HEALTH',
#        'POLICE DEPARTMENT', 'PROVIDENT HOSPITAL', 'STATES ATTORNEY',
#        'CORPORATE', 'STROGER HOSPITAL OF COOK CNTY', 'PUBLIC DEFENDER',
#        'OFFICE OF THE CHIEF JUDGE', 'COURT SERVICES DIVISION',
#        'DEPARTMENT OF CORRECTIONS', "SHERIFF'S ADMIN AND HR",
#        'AMBULATORY COMMUNITY HLTH NTWK', 'DEPT. OF FACILITIES/MGMT',
# ...

# %% [markdown]
# # find the no.of distinct bereaues

# %%
new_emp['Bureau'].nunique()
# Out:
# 110

# %% [markdown]
# # distinct office ids from the data

# %%
new_emp['Office_id'].unique()
# Out:
# array([1250., 1040., 4891., 1032., 4890., 4897., 1500., 1007., 4896.,
#        1280., 1239., 4893., 1060., 4240., 1231., 1205., 1326., 1440.,
#        1110., 1260., 1335., 4894., 1230., 1014., 1310., 4241., 1214.,
#        1305., 1130., 1009., 4898., 1200., 1020., 1300., 1011., 1050.,
#        1265., 1080., 1217., 1010., 4895., 1259., 1216., 1160., 1022.,
#        1210., 1016., 1031., 1313., 1087., 1312., 1030., 1021., 1161.,
#        1096., 1088., 1249., 1008., 1236., 1070., 1026., 1081., 1083.,
#        1013., 1586., 1029., 1027., 1002., 1082., 1086., 1084., 1451.,
#        1390., 1018., 1092., 1085., 1093., 1090., 1091., 1095., 1170.,
#        1094., 1525., 1089., 1097., 1896., 1897., 1240., 1622., 1895.,
#        1894., 1524., 1769., 1898., 1893., 1544., 1782., 1781., 1534.,
#        1612., 1890., 1979., 1891., 1918., 1942., 1501., 1632., 1903.,
#        1975., 1779., 1535., 1909., 1729., 1615., 1974., 1793., 1680.,
# ...

# %%
new_emp['Office_id'] = new_emp['Office_id'].astype(int)

# %%
new_emp['Office_id'].unique()
# Out:
# array([1250, 1040, 4891, 1032, 4890, 4897, 1500, 1007, 4896, 1280, 1239,
#        4893, 1060, 4240, 1231, 1205, 1326, 1440, 1110, 1260, 1335, 4894,
#        1230, 1014, 1310, 4241, 1214, 1305, 1130, 1009, 4898, 1200, 1020,
#        1300, 1011, 1050, 1265, 1080, 1217, 1010, 4895, 1259, 1216, 1160,
#        1022, 1210, 1016, 1031, 1313, 1087, 1312, 1030, 1021, 1161, 1096,
#        1088, 1249, 1008, 1236, 1070, 1026, 1081, 1083, 1013, 1586, 1029,
#        1027, 1002, 1082, 1086, 1084, 1451, 1390, 1018, 1092, 1085, 1093,
#        1090, 1091, 1095, 1170, 1094, 1525, 1089, 1097, 1896, 1897, 1240,
#        1622, 1895, 1894, 1524, 1769, 1898, 1893, 1544, 1782, 1781, 1534,
#        1612, 1890, 1979, 1891, 1918, 1942, 1501, 1632, 1903, 1975, 1779,
#        1535, 1909, 1729, 1615, 1974, 1793, 1680, 1935, 1668, 1830, 1241,
#        1767, 1859, 1997, 1604, 1675, 1946, 1742, 1854, 1620, 1637, 1570,
#        1530])

# %% [markdown]
# # total no.of distinct office_ids from the data

# %%
new_emp['Office_id'].nunique()
# Out:
# 133

# %% [markdown]
# # find distinct office names

# %%
new_emp['Office Name'].unique()
# Out:
# array(['STATES ATTORNEY', 'COUNTY ASSESSOR', 'PROVIDENT HOSPITAL',
#        'DEPT. OF HUMAN RESOURCES', 'BUREAU OF HEALTH',
#        'STROGER HOSPITAL OF COOK CNTY', 'DEPT. OF TRANSPORTATION AND HW',
#        'REVENUE', 'MANAGED CARE', 'ADULT PROBATION DEPT.',
#        'DEPARTMENT OF CORRECTIONS', 'AMBULATORY COMMUNITY HLTH NTWK',
#        'COUNTY TREASURER', 'CERMAK HEALTH SERVICES', 'POLICE DEPARTMENT',
#        'JUSTICE ADVISORY COUNCIL', 'JUVENILE PROBATION',
#        'JUVENILE TEMPORARY DETENT.CNTR', 'COUNTY CLERK',
#        'PUBLIC DEFENDER', 'CLERK OF CRCT CRT OFF. OF CLER',
#        'BOH SERVICES CORE CENTER', 'COURT SERVICES DIVISION',
#        'BUDGET & MANAGEMENT SERVICES', 'OFFICE OF THE CHIEF JUDGE',
#        'JTDC - HEALTH SERVICES', "SHERIFF'S ADMIN AND HR",
#        'PUBLIC GUARDIAN', 'RECORDER OF DEEDS',
#        'TECHNOLOGY POLICY AND PLANNING', 'OAK FOREST HEALTH CENTER',
#        'DEPT. OF FACILITIES/MGMT', 'COUNTY COMPTROLLER', 'JUDICIARY',
# ...

# %% [markdown]
# # find no.of distinct number of office names from the data set

# %%
new_emp['Office Name'].nunique()
# Out:
# 160

# %% [markdown]
# # find distinct number of job codes

# %%
new_emp['Job Code'].nunique()
# Out:
# 2380

# %%
new_emp['Job Code'].unique()
# Out:
# array([1172, 5049, 1642, ...,  837, 7054, 6985], dtype=int64)

# %%
new_emp['Job Title'].unique()
# Out:
# array(["Assistant State's Attorney", 'Residential Model Sr Anal III',
#        'Attending Physician XII', ..., 'Dep Asr,Chief Assment Op & Adm',
#        'Law Librarian III', 'Research Associate - CCHHS'], dtype=object)

# %% [markdown]
# # Distinct number of job titles from the data

# %%
new_emp['Job Title'].nunique()
# Out:
# 2382

# %%
new_emp['Original Hire Date'].unique()
# Out:
# array(['05/16/2005', '09/28/1998', '12/16/2013', ..., '03/18/2018',
#        '03-01-2012', '02/22/2004'], dtype=object)

# %% [markdown]
# # find how many days that employees has hired

# %%
new_emp['Original Hire Date'].nunique()
# Out:
# 3852

# %% [markdown]
# # find recent hired data from the data set and details

# %%
emp_hired_data=new_emp.sort_values(by='Original Hire Date',ascending =False)

# %%
emp_hired_data
# Out:
#         Fiscal Year  Fiscal Quarter        Full_name  \
# 30884          2017               4     MARA COLEMAN
# 30783          2017               2     MARA COLEMAN
# 63697          2017               3      DERRIE HALE
# 30834          2017               3     MARA COLEMAN
# 191837         2018               1      DERRIE HALE
# ...             ...             ...              ...
# 232656         2018               1  ALEXANDER WHITE
# 174347         2016               4  ALEXANDER WHITE
# 174246         2016               2  ALEXANDER WHITE
# 174193         2016               1  ALEXANDER WHITE
# 116682         2017               1    GENE NIEZGODA
#
#                                 Bureau  Office_id  \
# 30884                         Assessor       1040
# 30783                         Assessor       1040
# 63697                      Chief Judge       1440
# 30834                         Assessor       1040
# 191837  JUVENILE TEMPORARY DETENT.CNTR       1440
# ...

# %% [markdown]
# # find most recent hired date from the data set

# %%
most_recent_hire_date = emp_hired_data['Original Hire Date'].iloc[0]

# %%
most_recent_hire_date
# Out:
# '12/31/2013'

# %% [markdown]
# # find names of those employees who had hired on most recent date of hire

# %%
recent_hires = new_emp[new_emp['Original Hire Date'] == most_recent_hire_date]

# %%
print(recent_hires['Full_name'].unique())
# Out:
# ['MARA COLEMAN' 'DERRIE HALE']

# %% [markdown]
# # display the recent hires with each feature in detail from the data set

# %%
recent_hires
# Out:
#         Fiscal Year  Fiscal Quarter     Full_name  \
# 30511          2016               1  MARA COLEMAN
# 30569          2016               2  MARA COLEMAN
# 30623          2016               3  MARA COLEMAN
# 30676          2016               4  MARA COLEMAN
# 30729          2017               1  MARA COLEMAN
# 30783          2017               2  MARA COLEMAN
# 30834          2017               3  MARA COLEMAN
# 30884          2017               4  MARA COLEMAN
# 63669          2016               1   DERRIE HALE
# 63675          2016               2   DERRIE HALE
# 63681          2016               3   DERRIE HALE
# 63685          2016               4   DERRIE HALE
# 63689          2017               1   DERRIE HALE
# 63693          2017               2   DERRIE HALE
# 63697          2017               3   DERRIE HALE
# 63701          2017               4   DERRIE HALE
# 191837         2018               1   DERRIE HALE
# 202230         2018               2   DERRIE HALE
# ...

# %% [markdown]
# # find the initial date of hired employees

# %%
initial_hire_date=emp_hired_data['Original Hire Date'].iloc[-1]

# %%
initial_hire_date
# Out:
# '01-01-1967'

# %% [markdown]
# # find the names of those employees who had hired at most starting stage

# %%
initial_hires = new_emp[new_emp['Original Hire Date'] == initial_hire_date]

# %%
print(initial_hires['Full_name'].unique())
# Out:
# ['GENE NIEZGODA' 'ALEXANDER WHITE']

# %% [markdown]
# # display the details of each features ralted to those who had hired at starting stage

# %%
initial_hires
# Out:
#         Fiscal Year  Fiscal Quarter        Full_name       Bureau  Office_id  \
# 116678         2016               1    GENE NIEZGODA  Chief Judge       1310
# 116679         2016               2    GENE NIEZGODA  Chief Judge       1310
# 116680         2016               3    GENE NIEZGODA  Chief Judge       1310
# 116681         2016               4    GENE NIEZGODA  Chief Judge       1310
# 116682         2017               1    GENE NIEZGODA  Chief Judge       1310
# 116683         2017               2    GENE NIEZGODA  Chief Judge       1310
# 116684         2017               3    GENE NIEZGODA  Chief Judge       1310
# 174193         2016               1  ALEXANDER WHITE  Chief Judge       1300
# 174246         2016               2  ALEXANDER WHITE  Chief Judge       1300
# 174297         2016               3  ALEXANDER WHITE  Chief Judge       1300
# 174347         2016               4  ALEXANDER WHITE  Chief Judge       1300
# ...

# %% [markdown]
# # find out the details of employees who had a maximum base pay

# %%
max_basepay = new_emp['Base Pay'].max()
max_basepay_employees = new_emp[new_emp['Base Pay'] == max_basepay]

# %%
max_basepay_employees
# Out:
#         Fiscal Year  Fiscal Quarter      Full_name  \
# 232542         2018               1  PETER EGOFSKE
#
#                                Bureau  Office_id  \
# 232542  STROGER HOSPITAL OF COOK CNTY       4897
#
#                           Office Name  Job Code                   Job Title  \
# 232542  STROGER HOSPITAL OF COOK CNTY      6563  Attend Physician Sr XII SC
#
#          Base Pay  Position ID Original Hire Date
# 232542  242576.34       300233         07/15/1999

# %% [markdown]
# # find out the details of employees who had a minimum base pay

# %%
min_basepay = new_emp['Base Pay'].min()
min_basepay_employees = new_emp[new_emp['Base Pay'] == min_basepay]

# %%
min_basepay_employees
# Out:
#       Fiscal Year  Fiscal Quarter     Full_name            Bureau  Office_id  \
# 1383         2016               4  MUNEEZA AFIF  Bureau of Health       4893
#
#                          Office Name  Job Code               Job Title  \
# 1383  AMBULATORY COMMUNITY HLTH NTWK      1636  Attending Physician VI
#
#       Base Pay  Position ID Original Hire Date
# 1383 -19562.15       700085         07-01-2012

# %% [markdown]
# # findout the average_base pay amount

# %%
average_basepay=new_emp['Base Pay'].mean()

# %%
average_basepay
# Out:
# 16887.98981653837

# %% [markdown]
# # list down the details of employees from the data set who has been getting below average base pay amount

# %%
belowAvg_basepay_employees=new_emp[new_emp['Base Pay']<=average_basepay]

# %%
belowAvg_basepay_employees
# Out:
#         Fiscal Year  Fiscal Quarter            Full_name  \
# 23             2016               3          RUTH ABARCA
# 29             2017               2  GLADYS ABARCA-LOPEZ
# 41             2016               1          SALLY ABBAS
# 43             2016               3          SALLY ABBAS
# 45             2017               1          SALLY ABBAS
# ...             ...             ...                  ...
# 234286         2018               2        EDWARD HOWARD
# 234290         2018               2           SARI MARSH
# 234291         2018               2        KEITH HERRERA
# 234297         2018               1         LAURA TOLEDO
# 234298         2018               2     NAKIA WASHINGTON
#
#                                 Bureau  Office_id  \
# 23           Bureau of Human Resources       1032
# 29                    Bureau of Health       4890
# 41                    Bureau of Health       4897
# 43                    Bureau of Health       4897
# ...

# %% [markdown]
# # no.of employees who had been getting below average base pay

# %%
belowAvg_basepay_employees['Full_name'].nunique()
# Out:
# 23159

# %% [markdown]
# # list down the details of employees from the data set who has been getting above average base pay amount

# %%
aboveAvg_basepay_employees=new_emp[new_emp['Base Pay']>=average_basepay]

# %%
aboveAvg_basepay_employees
# Out:
#         Fiscal Year  Fiscal Quarter             Full_name  \
# 0              2016               1          AMRITH AAKRE
# 1              2016               2          AMRITH AAKRE
# 2              2016               3          AMRITH AAKRE
# 3              2016               4          AMRITH AAKRE
# 4              2017               1          AMRITH AAKRE
# ...             ...             ...                   ...
# 234292         2018               2  IYEKEORETI DJIRACKOR
# 234293         2018               1      ABELARDO MERCADO
# 234294         2018               2      NORMA AMOFA-LOZA
# 234295         2018               2        FRANK PHILLIPS
# 234296         2018               1      CYNTHIA KENDRICK
#
#                                Bureau  Office_id  \
# 0                    State's Attorney       1250
# 1                    State's Attorney       1250
# 2                    State's Attorney       1250
# 3                    State's Attorney       1250
# ...

# %% [markdown]
# # No.of employees from the data set who has been getting above average base pay amount

# %%
aboveAvg_basepay_employees['Full_name'].nunique()
# Out:
# 15616

# %% [markdown]
# # list down the year wise data of different fiscal quarters

# %%
year_wise_data = new_emp[new_emp['Fiscal Year'] == 2017]

# %%
year_wise_data
# Out:
#         Fiscal Year  Fiscal Quarter        Full_name            Bureau  \
# 4              2017               1     AMRITH AAKRE  State's Attorney
# 5              2017               2     AMRITH AAKRE  State's Attorney
# 6              2017               3     AMRITH AAKRE  State's Attorney
# 11             2017               1     DAVID AARONS          Assessor
# 12             2017               2     DAVID AARONS          Assessor
# ...             ...             ...              ...               ...
# 181638         2017               3   LAURA ZYMANTAS           Sheriff
# 181643         2017               1  LANCE ZYTNOWSKI           Sheriff
# 181644         2017               2  LANCE ZYTNOWSKI           Sheriff
# 181645         2017               3  LANCE ZYTNOWSKI           Sheriff
# 181646         2017               4  LANCE ZYTNOWSKI           Sheriff
#
#         Office_id                Office Name  Job Code  \
# 4            1250            STATES ATTORNEY      1172
# ...

# %%
year_wise_data = new_emp[new_emp['Fiscal Year'] == 2016]
year_wise_data
# Out:
#         Fiscal Year  Fiscal Quarter        Full_name            Bureau  \
# 0              2016               1     AMRITH AAKRE  State's Attorney
# 1              2016               2     AMRITH AAKRE  State's Attorney
# 2              2016               3     AMRITH AAKRE  State's Attorney
# 3              2016               4     AMRITH AAKRE  State's Attorney
# 7              2016               1     DAVID AARONS          Assessor
# ...             ...             ...              ...               ...
# 181635         2016               4   LAURA ZYMANTAS           Sheriff
# 181639         2016               1  LANCE ZYTNOWSKI           Sheriff
# 181640         2016               2  LANCE ZYTNOWSKI           Sheriff
# 181641         2016               3  LANCE ZYTNOWSKI           Sheriff
# 181642         2016               4  LANCE ZYTNOWSKI           Sheriff
#
#         Office_id                Office Name  Job Code  \
# 0            1250            STATES ATTORNEY      1172
# ...

# %%
year_wise_data = new_emp[new_emp['Fiscal Year'] == 2018]
year_wise_data
# Out:
#         Fiscal Year  Fiscal Quarter            Full_name  \
# 181647         2018               1          KISHA JONES
# 181648         2018               1            GIA SHORT
# 181649         2018               1           BRIAN ZYCH
# 181650         2018               2         KEITH STRONG
# 181651         2018               1  MICHELLE ANYSZEWSKI
# ...             ...             ...                  ...
# 234294         2018               2     NORMA AMOFA-LOZA
# 234295         2018               2       FRANK PHILLIPS
# 234296         2018               1     CYNTHIA KENDRICK
# 234297         2018               1         LAURA TOLEDO
# 234298         2018               2     NAKIA WASHINGTON
#
#                                 Bureau  Office_id  \
# 181647                 PUBLIC GUARDIAN       1305
# 181648                          HEALTH       1896
# 181649               POLICE DEPARTMENT       1231
# 181650              PROVIDENT HOSPITAL       4891
# ...

# %% [markdown]
# # no.of employees from each job title and job code

# %%
employee_counts = new_emp.groupby(['Job Title', 'Job Code']).size().reset_index(name='Employee Count')
employee_counts
# Out:
#                            Job Title  Job Code  Employee Count
# 0               340B Program Analyst      6502               8
# 1               340B Program Manager      6503               9
# 2      ADA Compliance Project Direct      6241               9
# 3     ANIMAL CONTRL FIELD SUPERVISOR      1393              10
# 4      APN-CRNA Chief Nurse Anesthet      3994              10
# ...                              ...       ...             ...
# 2459         Youth Service Worker II      1317              11
# 2460            Zoning Administrator      1417              10
# 2461             Zoning Land Planner      1418              10
# 2462          Zoning Plan Examiner I      1420              10
# 2463         Zoning Plan Examiner II      1421              10
#
# [2464 rows x 3 columns]

# %%
employee_counts.sort_values(by='Employee Count',ascending=False)
# Out:
#                            Job Title  Job Code  Employee Count
# 704             Correctional Officer      1360           34427
# 633                 Clinical Nurse I      1941            9405
# 889                Deputy Sheriff II      1333            8207
# 167       Assistant State's Attorney      1172            7496
# 616                          Clerk V       907            6745
# ...                              ...       ...             ...
# 1276     Financial Room Clerk IV CCC      5624               1
# 1271  Financial Ops Coord - Assessor      5045               1
# 2395        Training Coordinator III       815               1
# 2183      Specifications Engineer II      2234               1
# 260    Attendant Patient Care As Req      2071               1
#
# [2464 rows x 3 columns]

# %% [markdown]
# # draw the plot that shows the no.of employees and job titles

# %%
plt.figure(figsize=(15, 3))
plt.bar(employee_counts['Job Title'], employee_counts['Employee Count'])
plt.xlabel('Job Title')
plt.ylabel('Employee Count')
plt.title('Employee Count by Job Title')
plt.xticks(rotation=90)
plt.show()

# %%
headcount=employee_counts.head(25)

# %%
headcount.sort_values(by='Employee Count',ascending=False)
# Out:
#                          Job Title  Job Code  Employee Count
# 8           APN-Nurse Practitioner      3990             507
# 12                   Accountant II       142             235
# 18                    Accountant V       145             146
# 14                  Accountant III       143             139
# 16                   Accountant IV       144             120
# 5   APN-Cert Reg Nurse Anesthetist      3993             103
# 10                    Accountant I       141             102
# 7    APN-Clinical Nurse Specialist      3991              73
# 11         Accountant I Senior CCC      5635              48
# 24          Accounts Payable Clerk      5518              48
# 13        Accountant II Senior CCC      5636              43
# 19                Accountant V-CCC      5676              20
# 21             Accountant VIII-CCC      5679              20
# 22              Accounting Analyst      6004              17
# ...

# %% [markdown]
# # display the plot in detail by considering top 25 records

# %%
plt.figure(figsize=(15, 3))
plt.bar(headcount['Job Title'], headcount['Employee Count'])
plt.xlabel('Job Title')
plt.ylabel('Employee Count')
plt.title('Employee Count by Job Title')
plt.xticks(rotation=90)
plt.show()

# %%
employee_counts.sort_values(by='Employee Count',ascending=False)
# Out:
#                            Job Title  Job Code  Employee Count
# 704             Correctional Officer      1360           34427
# 633                 Clinical Nurse I      1941            9405
# 889                Deputy Sheriff II      1333            8207
# 167       Assistant State's Attorney      1172            7496
# 616                          Clerk V       907            6745
# ...                              ...       ...             ...
# 1276     Financial Room Clerk IV CCC      5624               1
# 1271  Financial Ops Coord - Assessor      5045               1
# 2395        Training Coordinator III       815               1
# 2183      Specifications Engineer II      2234               1
# 260    Attendant Patient Care As Req      2071               1
#
# [2464 rows x 3 columns]

# %%
employee_counts.sort_values(by='Employee Count',ascending=False,inplace=True)
head_co=employee_counts.head(20)

# %% [markdown]
# # display the plot in descending order of no.of employees with their job titles

# %%
plt.figure(figsize=(15, 3))
plt.bar(head_co['Job Title'], head_co['Employee Count'])
plt.xlabel('Job Title')
plt.ylabel('Employee Count')
plt.title('Employee Count by Job Title')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # list down the no.of employees w.r.to each office name and office id

# %%
employee_counts = new_emp.groupby(['Office_id', 'Office Name']).size().reset_index(name='Employee Count')

# %%
employee_counts.sort_values(by='Employee Count',ascending=False)
# Out:
#      Office_id                     Office Name  Employee Count
# 108       1239       DEPARTMENT OF CORRECTIONS           40534
# 233       4897   STROGER HOSPITAL OF COOK CNTY           39979
# 144       1335  CLERK OF CRCT CRT OFF. OF CLER           16516
# 128       1250                 STATES ATTORNEY           12533
# 91        1230         COURT SERVICES DIVISION           11083
# ..         ...                             ...             ...
# 76        1214           Office of the Sheriff               1
# 157       1570               Engineer to Order               1
# 160       1604    MacArthur Safety and Justice               1
# 161       1604    SA Child Support Enforcement               1
# 187       1890   Department of Human Resources               1
#
# [235 rows x 3 columns]

# %% [markdown]
# # draw the plot that display the no.of employees in each officeId and office names

# %%
plt.figure(figsize=(15, 3))
plt.bar(employee_counts['Office Name'], employee_counts['Employee Count'])
plt.xlabel('Office Name')
plt.ylabel('Employee Count')
plt.title('Employee Count by Office Name')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # display the chart in clear way by considering top few records

# %%
employee_counts.sort_values(by='Employee Count',ascending=False,inplace=True)
head_coo=employee_counts.head(20)
plt.figure(figsize=(15, 3))
plt.bar(head_coo['Office Name'], head_coo['Employee Count'])
plt.xlabel('Office Name')
plt.ylabel('Employee Count')
plt.title('Employee Count by Office Name')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # find no.of employees in each Bureau

# %%
employee_counts = new_emp.groupby(['Bureau']).size().reset_index(name='Employee Count')

# %%
employee_counts.sort_values(by='Employee Count',ascending=False)
# Out:
#                              Bureau  Employee Count
# 16                 Bureau of Health           52802
# 101                         Sheriff           51727
# 30                      Chief Judge           24244
# 31             Clerk of Circuit Ct.           12928
# 102                State's Attorney           10112
# ..                              ...             ...
# 107                TWELFTH DISTRICT               8
# 5    BOARD OF ELEC COMM-ELECTION FU               8
# 43                ELEVENTH DISTRICT               6
# 109         ZONING BOARD OF APPEALS               6
# 38       DEPT OF ENVIRONMENTAL CTRL               2
#
# [110 rows x 2 columns]

# %% [markdown]
# # Extract the few insights form the above data

# %%
cheif_judge=employee_counts[employee_counts['Bureau']=='Chief Judge']

# %%
cheif_judge
# Out:
#          Bureau  Employee Count
# 30  Chief Judge           24244

# %%
Clerk_of_Circuit=employee_counts[employee_counts['Bureau']=='Clerk of Circuit Ct.']

# %%
Clerk_of_Circuit
# Out:
#                   Bureau  Employee Count
# 31  Clerk of Circuit Ct.           12928

# %%
new_emp[new_emp['Bureau']=='JUDICIARY']
# Out:
#         Fiscal Year  Fiscal Quarter         Full_name     Bureau  Office_id  \
# 181695         2018               2    CLARENCE BURCH  JUDICIARY       1300
# 181788         2018               2     MYRON MACKOFF  JUDICIARY       1300
# 181798         2018               2      PAUL KARKULA  JUDICIARY       1300
# 181848         2018               2       LISA CURCIO  JUDICIARY       1300
# 181971         2018               1  STEPHANIE MILLER  JUDICIARY       1300
# ...             ...             ...               ...        ...        ...
# 234079         2018               2      MATTHEW LINK  JUDICIARY       1300
# 234082         2018               2    ARTHUR HILL JR  JUDICIARY       1300
# 234202         2018               2   VINCENT GAUGHAN  JUDICIARY       1300
# 234221         2018               2      MICHAEL OTTO  JUDICIARY       1300
# 234270         2018               2   GREGORY VAZQUEZ  JUDICIARY       1300
#
# ...

# %%
judiciary_counts=employee_counts[employee_counts['Bureau']=='JUDICIARY']

# %%
judiciary_counts
# Out:
#        Bureau  Employee Count
# 57  JUDICIARY             793

# %%
employee_counts = new_emp.groupby(['Office_id', 'Office Name']).size().reset_index(name='Employee Count')
employee_counts.sort_values(by='Employee Count', ascending=False,inplace=True)
headd=employee_counts.head(100)

# %% [markdown]
# # Visualize the percentage of employees in each office with

# %%
plt.figure(figsize=(5,5))
plt.pie(headd['Employee Count'], labels=headd['Office Name'], autopct='%1.1f%%')
plt.title('Employee Count by Office Name')
plt.axis('equal')
plt.show()

# %% [markdown]
# # plot the chart of histogram of distributing the base pay

# %%
plt.figure(figsize=(15, 6))
plt.hist(new_emp['Base Pay'], bins=20)
plt.xlabel('Base Pay')
plt.ylabel('Frequency')
plt.title('Distribution of Base Pay')
plt.show()

# %% [markdown]
# # Scatter plot for base pay of different fiscal years

# %%
plt.figure(figsize=(10, 6))
plt.scatter(new_emp['Fiscal Year'], new_emp['Base Pay'])
plt.xlabel('Fiscal Year')
plt.ylabel('Base Pay')
plt.title('Base Pay by Fiscal Year')
plt.show()

# %% [markdown]
# # plot the box plot to visualize the base pay distribution over the employees with their max, min and average base pays

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(new_emp['Base Pay'])
plt.ylabel('Base Pay')
plt.title('Distribution of Base Pay')
plt.show()

# %%
plt.figure(figsize=(10, 3))
plt.plot(new_emp['Fiscal Year'], new_emp['Base Pay'])
plt.xlabel('Fiscal Year')
plt.ylabel('Base Pay')
plt.title('Base Pay by Fiscal Year')
plt.grid(True)
plt.show()

# %%
employee_counts = new_emp.groupby(['Bureau']).size().reset_index(name='Employee Count')
hedo=employee_counts.sort_values(by='Employee Count',ascending=False)

# %%
hedo=hedo.head(25)

# %% [markdown]
# # Visualize the no.of employees in each Bureau by bar plot

# %%
plt.figure(figsize=(15,3))
plt.bar(hedo['Bureau'], hedo['Employee Count'])
plt.xlabel('Bureau')
plt.ylabel('Employee Count')
plt.title('Employee Count by Bureau')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Visualize the percentage of employees in each Bureau

# %%
plt.figure(figsize=(5,5))
plt.pie(hedo['Employee Count'], labels=hedo['Bureau'], autopct='%1.1f%%')
plt.title('Employee Count by Bureau')
plt.axis('equal')
plt.show()
